# %%
autoencoder.save("my_autoencoder.keras")
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 autoencoder.save("my_autoencoder.keras")
#
# NameError: name 'autoencoder' is not defined
